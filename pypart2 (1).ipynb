# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Read dataset
df = pd.read_csv(r"C:\Users\Lenovo\loan_data_set.csv")

print("Initial Data:")
print(df.head(), "\n")

# Handle missing values
df.ffill(inplace=True)
df.bfill(inplace=True)

# Encode categorical columns (only existing ones)
df1 = pd.get_dummies(df, columns=["Gender", "Married", "Loan_Status"], drop_first=True)

print("After Encoding:")
print(df1.head(), "\n")

# Split into features and target
x = df1.drop(["Loan_ID", "Loan_Status_Y"], axis=1)
y = df1["Loan_Status_Y"]

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# --- Model Training ---

# Logistic Regression
log_model = LogisticRegression(max_iter=500)
log_model.fit(x_train, y_train)
y_pred_log = log_model.predict(x_test)

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=0)
dt_model.fit(x_train, y_train)
y_pred_dt = dt_model.predict(x_test)

# Random Forest
rf_model = RandomForestClassifier(n_estimators=100, random_state=0)
rf_model.fit(x_train, y_train)
y_pred_rf = rf_model.predict(x_test)

# Support Vector Machine
svm_model = SVC(kernel='linear', random_state=0)
svm_model.fit(x_train, y_train)
y_pred_svm = svm_model.predict(x_test)

# K-Nearest Neighbors
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(x_train, y_train)
y_pred_knn = knn_model.predict(x_test)

# --- Results ---

print("Model Accuracies:")
print("Logistic Regression:", accuracy_score(y_test, y_pred_log))
print("Decision Tree:", accuracy_score(y_test, y_pred_dt))
print("Random Forest:", accuracy_score(y_test, y_pred_rf))
print("SVM:", accuracy_score(y_test, y_pred_svm))
print("KNN:", accuracy_score(y_test, y_pred_knn))

print("\nConfusion Matrices:")
print("Logistic Regression:\n", confusion_matrix(y_test, y_pred_log))
print("Decision Tree:\n", confusion_matrix(y_test, y_pred_dt))
print("Random Forest:\n", confusion_matrix(y_test, y_pred_rf))
print("SVM:\n", confusion_matrix(y_test, y_pred_svm))
print("KNN:\n", confusion_matrix(y_test, y_pred_knn))
# Out:
# Initial Data:
#   Loan_ID  Gender Married  ApplicantIncome  LoanAmount Loan_Status
# 0    L001    Male     Yes             5000         200           Y
# 1    L002  Female      No             3000         120           N
# 2    L003    Male     Yes             4000         150           Y
# 3    L004    Male      No             2500         100           N
# 4    L005  Female     Yes             6000         250           Y
#
# After Encoding:
#   Loan_ID  ApplicantIncome  LoanAmount  Gender_Male  Married_Yes  \
# 0    L001             5000         200         True         True
# 1    L002             3000         120        False        False
# 2    L003             4000         150         True         True
# 3    L004             2500         100         True        False
# 4    L005             6000         250        False         True
#
#    Loan_Status_Y
# 0           True
# 1          False
# 2           True
# 3          False
# 4           True
#
# Model Accuracies:
# ...
